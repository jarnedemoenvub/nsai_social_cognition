# %%
import os
import torch
import torchvision.models as models
import torch.nn as nn
# from deepproblog.dataset import Dataset, DataLoader, QueryDataset
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as TorchDataset
from deepproblog.dataset import Dataset as DPLDataset
from problog.logic import Term, Constant, Var, list2term
from deepproblog.dataset import ImageDataset
from deepproblog.evaluate import get_confusion_matrix
from torch.amp.autocast_mode import autocast
from torchvision import models, transforms, datasets
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from deepproblog.dataset import DataLoader as DPLDataLoader

import torch.optim as optim
from torchvision import models, transforms
from PIL import Image
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np
import random
from deepproblog.utils.stop_condition import EpochStop
from deepproblog.optimizer import SGD

from deepproblog.model import Model
from deepproblog.network import Network
from deepproblog.engines import ExactEngine
from deepproblog.query import Query
from deepproblog.train import train_model
import torch.nn as nn
import torch.nn.functional as F

from torch.amp.grad_scaler import GradScaler
from torch.amp.autocast_mode import autocast

from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import glob
from retinaface import RetinaFace
import csv

# %%
# GLOBAL VARS
dataset_size = None
batch_size = 32
log_iter = 2
global_emotion_label = 'emo3'

# %%
# Directories
script_dir = os.getcwd()
print("script_dir:", script_dir)
base_dir = os.path.dirname(os.path.dirname(script_dir))
print("base_dir:", base_dir)
prolog_dir = os.path.join(base_dir, "prolog")
data_dir = os.path.join(base_dir, "data")
print("data_dir:", data_dir)
findingemo_dir = os.path.join(data_dir, "FindingEmo_Images")
print("findingemo_dir:", findingemo_dir)
prolog_dir = os.path.join(base_dir, "code", "prolog")
print("prolog_dir:", prolog_dir)
model_dir = os.path.join(base_dir, "code", "models")
print("model_dir:", model_dir)
cropped_faces_dir = os.path.join(findingemo_dir, "faces")
print("cropped_faces_dir:", cropped_faces_dir)
# Out:
# script_dir: c:\Users\jarne\Documents\Code Masterthesis\nsai_social_cognition\code\notebooks
# base_dir: c:\Users\jarne\Documents\Code Masterthesis\nsai_social_cognition
# data_dir: c:\Users\jarne\Documents\Code Masterthesis\nsai_social_cognition\data
# findingemo_dir: c:\Users\jarne\Documents\Code Masterthesis\nsai_social_cognition\data\FindingEmo_Images
# prolog_dir: c:\Users\jarne\Documents\Code Masterthesis\nsai_social_cognition\code\prolog
# model_dir: c:\Users\jarne\Documents\Code Masterthesis\nsai_social_cognition\code\models
# cropped_faces_dir: c:\Users\jarne\Documents\Code Masterthesis\nsai_social_cognition\data\FindingEmo_Images\faces

# %%
df = pd.read_pickle(os.path.join(script_dir, "clean_findingemo.pkl"))
print("Dataframe loaded. Number of entries:", len(df))
# Out:
# Dataframe loaded. Number of entries: 25867

# %%
EMOTION_SETS = [["Serenity", "Joy", "Ecstasy"],
                    ["Acceptance", "Trust", "Admiration"],
                    ["Apprehension", "Fear", "Terror"],
                    ["Distraction", "Surprise", "Amazement"],
                    ["Pensiveness", "Sadness", "Grief"],
                    ["Boredom", "Disgust", "Loathing"],
                    ["Annoyance", "Anger", "Rage"],
                    ["Interest", "Anticipation", "Vigilance"]]
                
def emo_8_mapping(e):
    for leaf in EMOTION_SETS:
        if e in leaf:
            return leaf[1]
        
def emo_3_mapping(v):
    if v < -1:
        return "sad"
    if v > 1:
        return "happy"
    else:
        return "neutral"

# %%
if global_emotion_label == 'emo8':
    df['emotion'] = df['emotion'].apply(emo_8_mapping).str.lower()
if global_emotion_label == 'emotion':
    df['emotion'] = df['emotion'].str.lower()
if global_emotion_label == 'emo3':
    df['emotion'] = df['valence'].apply(emo_3_mapping).str.lower()

# %%
df.head()
# Out:
#                                           image_path       tags           age  \
# 0        Run_2/Loving toddlers sports/haiti-kids.jpg  Undefined      Children
# 1  Run_2/Frustrated forty-something office/team-w...  Undefined  Young Adults
# 2        Run_1/Violent youth festival/1042373588.jpg  Undefined  Young Adults
# 3  Run_2/Remorseful toddlers court of law/dcfs-co...  Undefined        Adults
# 4          Run_2/Shame elderly sports/3364887-46.jpg  Undefined        Adults
#
#    valence  arousal  emotion                    dec_factors  ambiguity
# 0        0        2  neutral  BodyLanguage,FacialExpression          0
# 1        0        2  neutral               FacialExpression          0
# 2        2        2    happy                   BodyLanguage          3
# 3        1        2  neutral  BodyLanguage,FacialExpression          4
# 4        0        3  neutral             ConflictCtxtPerson          0

# %%
len(df)
# Out:
# 25867

# %%
if dataset_size is not None:
    df = df.iloc[:dataset_size]

# %%
fe_labels = df['emotion'].unique().tolist()
fe_labels.sort()
print("Emotion labels:", fe_labels)
# Out:
# Emotion labels: ['happy', 'neutral', 'sad']

# %%
fer_classes = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
# Load category names
scene_categories_path = os.path.join(data_dir, "places365/categories_places365.txt")
with open(scene_categories_path) as f:
    scene_categories = [line.strip().split(' ')[0][3:] for line in f]
    # If there is a / in the category name, replace it with _
    scene_categories = [cat.replace('/', '_') for cat in scene_categories]
print("Length of scene categories:", len(scene_categories))  # Should be 365
# Out:
# Length of scene categories: 365

# %%
# get the counts of the labels of emotion
df['emotion'].value_counts()
# Out:
# emotion
# neutral    12776
# happy       8192
# sad         4899
# Name: count, dtype: int64

# %%
if dataset_size is not None:
    N = dataset_size
else:
    N = len(df)
    
indices = list(range(N))

train_indices, test_indices = train_test_split(indices, test_size=0.2, random_state=42)
print("Train indices length:", len(train_indices))
print("Test indices length:", len(test_indices))
# Out:
# Train indices length: 20693
# Test indices length: 5174

# %%
print(torch.cuda.is_available())
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# let cuDNN pick the fastest kernels for this image size
# torch.backends.cudnn.benchmark = True
# Out:
# True

# %%
from transformers import AutoImageProcessor, AutoModelForImageClassification, AutoConfig

emotion_transform = AutoImageProcessor.from_pretrained("trpakov/vit-face-expression", use_fast=True)
face_model_base = AutoModelForImageClassification.from_pretrained("trpakov/vit-face-expression")
face_model_base.to(DEVICE)
config = AutoConfig.from_pretrained("trpakov/vit-face-expression")
print(config.id2label)
# Out:
# {0: 'angry', 1: 'disgust', 2: 'fear', 3: 'happy', 4: 'neutral', 5: 'sad', 6: 'surprise'}

# %%
scene_processor = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Load pretrained Places365 ResNet18
scene_model_base = models.resnet18(num_classes=365)
weights_url = "http://places2.csail.mit.edu/models_places365/resnet18_places365.pth.tar"
checkpoint = torch.hub.load_state_dict_from_url(weights_url, map_location="cpu")
state_dict = {k.replace("module.", ""): v for k, v in checkpoint["state_dict"].items()}
scene_model_base.load_state_dict(state_dict)
scene_model_base.to(DEVICE)
print("Loaded pretrained models")
# Out:
# Loaded pretrained models

# %%
df_boxes = pd.read_csv(os.path.join(findingemo_dir, "face_boxes_5.csv"))
# Based on boxes_df we can add the column nr_faces for each original image in df
df['nr_faces'] = df.index.map(df_boxes['index'].value_counts()).fillna(0).astype(int)

# %%
get_category_name = lambda idx: scene_categories[idx]

# %%
scene_priors_path = os.path.join(data_dir, "scene_priors.xlsx")
scene_priors = pd.read_excel(scene_priors_path, index_col=0)
scene_priors.head()
# Out:
#                    valence   arousal  nr_samples
# scene_category
# airfield          4.000000  3.000000           2
# airplane_cabin    3.059829  3.025641         117
# airport_terminal  2.952381  2.190476          42
# alcove            4.000000  1.000000           1
# alley             3.130435  2.608696          23

# %%
# Load scene priors from excel and change the nan values to None
scene_priors = {}
df_loaded = pd.read_excel(os.path.join(data_dir, "scene_priors.xlsx"))
for _, row in df_loaded.iterrows():
    scene_name = row['scene_category']
    valence = row['valence'] if not pd.isna(row['valence']) else None
    arousal = row['arousal'] if not pd.isna(row['arousal']) else None
    nr_samples = row['nr_samples'] if not pd.isna(row['nr_samples']) else 0
    scene_priors[scene_name] = (valence, arousal, nr_samples)

import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm

def cluster_places_categories_weighted(scene_priors, n_clusters=10):
    valid_scenes = []
    features = []
    weights = []

    # Extract valid scenes
    for scene_name, (valence, arousal, nr_samples) in tqdm(scene_priors.items(), desc="Filtering scenes"):
        if valence is not None and arousal is not None:
            valid_scenes.append(scene_name)
            features.append([valence, arousal])
            weights.append(nr_samples)

    features = np.array(features)
    weights = np.array(weights)

    print(f"Valid scenes: {len(valid_scenes)}/{len(scene_priors)}")
    print(f"Total samples: {weights.sum()}")

    # Standardize the features
    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features)

    # True weighted KMeans
    kmeans = KMeans(
        n_clusters=n_clusters,
        random_state=42,
        n_init=10,
    )

    # Fit with sample_weight (this is TRUE weighted K-Means)
    kmeans.fit(features_scaled, sample_weight=weights)

    # Assign cluster labels directly
    labels = kmeans.labels_

    # Build dictionary mapping scene → cluster
    cluster_labels = {
        scene: int(cluster)
        for scene, cluster in zip(valid_scenes, labels)
    }

    # Convert centers back to original valence/arousal scale
    cluster_centers = scaler.inverse_transform(kmeans.cluster_centers_)

    return cluster_labels, cluster_centers, features, valid_scenes, weights

# Run clustering
cluster_labels, cluster_centers, scene_features, valid_scenes, scene_weights = cluster_places_categories_weighted(
    scene_priors, 
    n_clusters=5)

# Print cluster statistics
print("\nCluster Statistics:")
for cluster_id in range(len(cluster_centers)):
    scenes_in_cluster = [s for s, c in cluster_labels.items() if c == cluster_id]
    total_samples = sum(scene_priors[s][2] for s in scenes_in_cluster)
    avg_valence = cluster_centers[cluster_id][0]
    avg_arousal = cluster_centers[cluster_id][1]
    print(f"Cluster {cluster_id}: {len(scenes_in_cluster)} scenes, {total_samples} samples")
    print(f"  Center: Valence={avg_valence:.2f}, Arousal={avg_arousal:.2f}")
    print()


# Visualize clusters
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patheffects
def visualize_clusters_2d(cluster_labels, cluster_centers, scene_features, valid_scenes, scene_weights, scene_priors):
    """2D visualization of clusters on valence-arousal plane with cluster ID labels on each point."""
    plt.figure(figsize=(14, 10))
    
    # Colors for each cluster
    colors = plt.cm.tab20(np.linspace(0, 1, len(cluster_centers)))
    
    for i, scene_name in enumerate(valid_scenes):
        cluster_id = cluster_labels[scene_name]
        valence, arousal = scene_features[i]
        size = np.log1p(scene_weights[i]) * 20
        
        # Scatter point
        plt.scatter(valence, arousal, 
                    c=[colors[cluster_id]], 
                    s=size, 
                    alpha=0.75, 
                    edgecolors='black', 
                    linewidth=0.5)
        
        # Add cluster ID text next to the point
        plt.text(valence, arousal, str(cluster_id),
                 fontsize=8, 
                 ha='center', va='center',
                 color='white',
                 path_effects=[
                     mpl.patheffects.Stroke(linewidth=1.5, foreground='black'),
                     mpl.patheffects.Normal()
                 ])
    
    # Plot cluster centers
    plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], 
                c='red', s=300, marker='X', edgecolors='black', linewidth=2, 
                label='Cluster Centers', zorder=5)
    
    # Annotate cluster centers
    for i, (v, a) in enumerate(cluster_centers):
        plt.annotate(f'C{i}', (v, a), fontsize=14, fontweight='bold', 
                     ha='left', va='center', color='white',
                     path_effects=[
                         mpl.patheffects.Stroke(linewidth=2, foreground='black'),
                         mpl.patheffects.Normal()
                     ])
    
    plt.xlabel('Valence', fontsize=14)
    plt.ylabel('Arousal', fontsize=14)
    plt.title('Places365 Categories Clustered by Valence-Arousal (weighted by samples)', fontsize=16)
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    # Print all scenes per cluster
    print("\n" + "="*80)
    print("DETAILED CLUSTER BREAKDOWN")
    print("="*80)
    for cluster_id in range(len(cluster_centers)):
        scenes_in_cluster = sorted([s for s, c in cluster_labels.items() if c == cluster_id])
        total_samples = sum(scene_priors[s][2] for s in scenes_in_cluster)
        avg_valence = cluster_centers[cluster_id][0]
        avg_arousal = cluster_centers[cluster_id][1]
        
        print(f"\n{'='*80}")
        print(f"CLUSTER {cluster_id}")
        print(f"{'='*80}")
        print(f"Center: Valence={avg_valence:.2f}, Arousal={avg_arousal:.2f}")
        print(f"Number of scenes: {len(scenes_in_cluster)}")
        print(f"Total samples: {total_samples}")
        print(f"\nAll scenes in this cluster:")
        print("-" * 80)
        
        for scene_name in scenes_in_cluster:
            v, a, n = scene_priors[scene_name]
            print(f"  • {scene_name:30s} | V={v:.2f}, A={a:.2f}, N={n:4d}")
        print()

visualize_clusters_2d(cluster_labels, cluster_centers, scene_features, valid_scenes, scene_weights, scene_priors)

# Now create a scatterplots of the cluster centers together with the valence arousal points of the emotions
def plot_clusters_with_emotions(cluster_centers):
    plt.figure(figsize=(12, 10))
    
    # Plot cluster centers
    plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], 
                c='red', s=300, marker='X', edgecolors='black', linewidth=2, 
                label='Cluster Centers', zorder=5)
    
    # Annotate cluster centers
    for i, (v, a) in enumerate(cluster_centers):
        plt.annotate(f'C{i}', (v, a), fontsize=14, fontweight='bold', 
                     ha='left', va='center', color='white',
                     path_effects=[
                         mpl.patheffects.Stroke(linewidth=2, foreground='black'),
                         mpl.patheffects.Normal()
                     ])
    
    # Plot emotion points
    for emo in df['emotion'].unique():
        subset = df[df['emotion'] == emo.lower()]
        avg_valence = subset['valence'].mean() + 3
        avg_arousal = subset['arousal'].mean()
        plt.scatter(avg_valence, avg_arousal, label=emo, s=150, alpha=0.7)
        plt.text(avg_valence, avg_arousal, emo,
                 fontsize=10, fontweight='bold',
                 ha='center', va='center',
                 color='black',
                 path_effects=[
                     mpl.patheffects.Stroke(linewidth=1.5, foreground='white'),
                     mpl.patheffects.Normal()
                 ])
    
    plt.xlabel('Valence', fontsize=14)
    plt.ylabel('Arousal', fontsize=14)
    plt.title('Places365 Cluster Centers with Emotion Averages', fontsize=16)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

plot_clusters_with_emotions(cluster_centers)


cluster_names = ["Cluster 0", "Cluster 1", "Cluster 2", "Cluster 3", "Cluster 4"]

# Find categories not in cluster_labels (those without valence/arousal data)
unassigned_categories = [cat for cat in scene_categories if cat not in cluster_labels]

# Randomly assign them to clusters
random.seed(42)  # For reproducibility
for cat in unassigned_categories:
    random_cluster = random.randint(0, len(cluster_centers) - 1)
    cluster_labels[cat] = random_cluster

# Verify all categories are now assigned
assert len(cluster_labels) == len(scene_categories), "Not all categories are assigned!"

# Update the cluster_dict with all categories
cluster_dict = {}
for cluster_id in range(len(cluster_centers)):
    scenes_in_cluster = sorted([s for s, c in cluster_labels.items() if c == cluster_id])
    cluster_dict[cluster_names[cluster_id]] = scenes_in_cluster
    print(f"Cluster {cluster_id} ({cluster_names[cluster_id]}): {len(scenes_in_cluster)} scenes")

# Convert to DataFrame and save
max_len = max(len(scenes) for scenes in cluster_dict.values())
for key in cluster_dict:
    scenes = cluster_dict[key]
    cluster_dict[key] = scenes + [""] * (max_len - len(scenes))

df_clusters = pd.DataFrame(cluster_dict)

# Save to Excel file
output_path = os.path.join(data_dir, f"scene_clusters_5.xlsx")
df_clusters.to_excel(output_path, index=False)

print(f"\nscene_clusters_5.xlsx saved to: {output_path}")
# Out:
# Filtering scenes: 100%|██████████| 365/365 [00:00<?, ?it/s]
# Valid scenes: 330/365
# Total samples: 41175
#
# Cluster Statistics:
# Cluster 0: 66 scenes, 6541 samples
#   Center: Valence=3.36, Arousal=2.56
#
# Cluster 1: 54 scenes, 9685 samples
#   Center: Valence=3.28, Arousal=2.92
#
# Cluster 2: 72 scenes, 8947 samples
#   Center: Valence=3.85, Arousal=3.12
#
# Cluster 3: 51 scenes, 8653 samples
#   Center: Valence=2.61, Arousal=3.09
#
# Cluster 4: 87 scenes, 7349 samples
#   Center: Valence=3.97, Arousal=2.60
# ================================================================================
# DETAILED CLUSTER BREAKDOWN
# ================================================================================
#
# ================================================================================
# CLUSTER 0
# ================================================================================
# Center: Valence=3.36, Arousal=2.56
# Number of scenes: 66
# Total samples: 6541
#
# All scenes in this cluster:
# --------------------------------------------------------------------------------
#   • airport_terminal               | V=2.95, A=2.19, N=  42
#   • alley                          | V=3.13, A=2.61, N=  23
#   • aquarium                       | V=3.21, A=2.50, N=  14
#   • arena_rodeo                    | V=3.41, A=2.65, N=  34
#   • art_gallery                    | V=3.56, A=2.48, N= 112
#   • barndoor                       | V=3.38, A=2.25, N=   8
#   • booth_indoor                   | V=3.65, A=2.38, N=  69
#   • bridge                         | V=3.00, A=2.00, N=   3
#   • bus_interior                   | V=3.37, A=2.68, N= 130
#   • bus_station_indoor             | V=3.12, A=2.62, N=  16
#   • butchers_shop                  | V=3.00, A=2.39, N=  23
#   • canal_urban                    | V=3.60, A=1.80, N=   5
#   • candy_store                    | V=3.17, A=1.83, N=   6
#   • chemistry_lab                  | V=3.59, A=2.60, N= 169
#   • childs_room                    | V=3.60, A=2.20, N=   5
#   • church_outdoor                 | V=3.57, A=2.71, N=   7
#   • clean_room                     | V=2.83, A=2.59, N=  54
#   • conference_center              | V=3.40, A=2.68, N=1641
#   • conference_room                | V=3.50, A=2.23, N= 117
#   • construction_site              | V=3.15, A=2.59, N= 158
#   • courtyard                      | V=3.67, A=1.83, N=   6
#   • dam                            | V=3.00, A=1.00, N=   1
#   • department_store               | V=3.00, A=2.62, N=  21
#   • doorway_outdoor                | V=3.00, A=2.00, N=   6
#   • dorm_room                      | V=3.57, A=2.52, N=  84
#   • downtown                       | V=3.47, A=2.63, N=  19
#   • drugstore                      | V=3.60, A=2.20, N=  10
#   • farm                           | V=3.50, A=1.95, N=  20
#   • field_cultivated               | V=3.57, A=1.57, N=   7
#   • fishpond                       | V=3.00, A=2.33, N=   3
#   • flea_market_indoor             | V=3.03, A=2.61, N= 206
#   • gas_station                    | V=2.85, A=2.59, N=  39
#   • gift_shop                      | V=3.50, A=2.00, N=   2
#   • golf_course                    | V=3.48, A=2.59, N=  88
#   • greenhouse_indoor              | V=3.62, A=2.12, N=   8
#   • hangar_indoor                  | V=3.58, A=1.92, N=  12
#   • hardware_store                 | V=3.59, A=1.82, N=  17
#   • hospital                       | V=3.41, A=2.18, N=  17
#   • jewelry_shop                   | V=3.27, A=2.64, N=  11
#   • kasbah                         | V=3.11, A=2.50, N=  18
#   • kennel_outdoor                 | V=3.23, A=2.54, N=  13
#   • lecture_room                   | V=3.49, A=2.45, N= 861
#   • legislative_chamber            | V=3.22, A=2.58, N=1536
#   • living_room                    | V=3.43, A=2.70, N=  46
#   • loading_dock                   | V=2.68, A=2.47, N=  19
#   • lobby                          | V=3.25, A=2.65, N=  20
#   • movie_theater_indoor           | V=3.17, A=2.43, N=  23
#   • office                         | V=3.53, A=2.58, N= 424
#   • physics_laboratory             | V=3.54, A=2.52, N= 162
#   • pizzeria                       | V=3.36, A=2.27, N=  11
#   • railroad_track                 | V=3.50, A=2.50, N=   2
#   • reception                      | V=3.55, A=2.30, N=  20
#   • restaurant_kitchen             | V=3.64, A=2.42, N=  72
#   • roof_garden                    | V=3.00, A=2.25, N=   8
#   • runway                         | V=3.44, A=2.60, N=  25
#   • schoolhouse                    | V=3.00, A=2.67, N=   3
#   • shower                         | V=3.40, A=2.60, N=   5
#   • ski_resort                     | V=3.11, A=2.56, N=   9
#   • sky                            | V=3.33, A=2.33, N=   6
#   • storage_room                   | V=2.80, A=2.00, N=   5
#   • sushi_bar                      | V=3.22, A=2.72, N=  18
#   • topiary_garden                 | V=3.09, A=2.64, N=  11
#   • tree_house                     | V=3.29, A=2.57, N=   7
#   • viaduct                        | V=3.00, A=2.00, N=   1
#   • water_tower                    | V=3.00, A=0.00, N=   1
#   • waterfall                      | V=2.50, A=2.00, N=   2
#
#
# ================================================================================
# CLUSTER 1
# ================================================================================
# Center: Valence=3.28, Arousal=2.92
# Number of scenes: 54
# Total samples: 9685
#
# All scenes in this cluster:
# --------------------------------------------------------------------------------
#   • airplane_cabin                 | V=3.06, A=3.03, N= 117
#   • amusement_park                 | V=3.32, A=3.33, N= 111
#   • archaelogical_excavation       | V=3.09, A=2.71, N= 323
#   • arena_hockey                   | V=3.51, A=2.97, N=  39
#   • auditorium                     | V=3.41, A=2.83, N=1016
#   • auto_showroom                  | V=3.40, A=2.90, N=  10
#   • bar                            | V=3.34, A=3.18, N=  71
#   • bazaar_indoor                  | V=3.11, A=3.02, N=  45
#   • beer_garden                    | V=3.28, A=2.93, N=1165
#   • beer_hall                      | V=3.51, A=2.92, N= 136
#   • boat_deck                      | V=3.05, A=3.05, N=  81
#   • bow_window_indoor              | V=3.52, A=2.90, N=  29
#   • boxing_ring                    | V=3.27, A=3.44, N= 324
#   • campsite                       | V=2.91, A=2.73, N=  82
#   • campus                         | V=3.26, A=2.76, N= 769
#   • carrousel                      | V=3.48, A=2.86, N=  21
#   • clothing_store                 | V=3.37, A=3.24, N=  75
#   • corral                         | V=3.31, A=2.81, N=  54
#   • desert_vegetation              | V=3.11, A=2.92, N= 101
#   • dressing_room                  | V=3.55, A=2.92, N= 221
#   • driveway                       | V=3.14, A=3.00, N=   7
#   • elevator_door                  | V=3.16, A=2.93, N= 178
#   • elevator_lobby                 | V=3.34, A=2.81, N= 108
#   • engine_room                    | V=3.23, A=3.62, N=  13
#   • entrance_hall                  | V=3.06, A=3.06, N=  17
#   • excavation                     | V=3.26, A=2.95, N=  19
#   • florist_shop_indoor            | V=2.92, A=2.92, N=  12
#   • forest_road                    | V=3.29, A=3.57, N=   7
#   • glacier                        | V=3.06, A=3.06, N=  16
#   • harbor                         | V=3.19, A=2.88, N=  16
#   • hospital_room                  | V=3.59, A=2.89, N= 726
#   • ice_skating_rink_indoor        | V=3.19, A=2.90, N=  52
#   • ice_skating_rink_outdoor       | V=3.05, A=2.77, N= 102
#   • locker_room                    | V=3.27, A=3.09, N= 172
#   • market_outdoor                 | V=2.99, A=2.82, N= 599
#   • medina                         | V=3.12, A=2.90, N= 220
#   • museum_indoor                  | V=3.30, A=2.90, N=  50
#   • music_studio                   | V=3.51, A=2.80, N= 140
#   • operating_room                 | V=3.09, A=3.08, N= 232
#   • palace                         | V=3.15, A=2.92, N=  13
#   • parking_lot                    | V=2.91, A=2.90, N= 249
#   • pier                           | V=3.17, A=3.04, N=  23
#   • promenade                      | V=2.89, A=2.79, N= 112
#   • pub_indoor                     | V=3.45, A=3.04, N= 235
#   • raft                           | V=3.16, A=3.09, N=  81
#   • river                          | V=3.27, A=3.20, N=  15
#   • stage_outdoor                  | V=3.17, A=3.09, N= 421
#   • subway_station_platform        | V=3.42, A=3.00, N=  12
#   • swamp                          | V=3.25, A=3.00, N=   8
#   • television_studio              | V=3.44, A=2.87, N= 742
#   • throne_room                    | V=3.00, A=2.86, N=   7
#   • train_interior                 | V=3.29, A=2.86, N= 146
#   • tree_farm                      | V=3.21, A=2.72, N= 119
#   • youth_hostel                   | V=3.62, A=2.88, N=  26
#
#
# ================================================================================
# CLUSTER 2
# ================================================================================
# Center: Valence=3.85, Arousal=3.12
# Number of scenes: 72
# Total samples: 8947
#
# All scenes in this cluster:
# --------------------------------------------------------------------------------
#   • airfield                       | V=4.00, A=3.00, N=   2
#   • amusement_arcade               | V=3.64, A=3.00, N=  11
#   • arch                           | V=6.00, A=4.00, N=   1
#   • arena_performance              | V=3.98, A=3.17, N= 632
#   • athletic_field_outdoor         | V=4.16, A=3.16, N= 354
#   • badlands                       | V=3.80, A=3.60, N=  10
#   • bakery_shop                    | V=6.00, A=5.00, N=   1
#   • ball_pit                       | V=3.77, A=2.86, N=  22
#   • ballroom                       | V=3.96, A=3.17, N= 157
#   • baseball_field                 | V=3.89, A=2.87, N= 205
#   • basketball_court_indoor        | V=4.21, A=3.23, N= 453
#   • beach                          | V=4.73, A=3.23, N=  48
#   • beauty_salon                   | V=3.65, A=2.99, N= 311
#   • bedchamber                     | V=4.00, A=4.00, N=   1
#   • bedroom                        | V=4.29, A=3.48, N=  21
#   • berth                          | V=5.00, A=3.33, N=   3
#   • botanical_garden               | V=4.25, A=3.75, N=   8
#   • butte                          | V=4.75, A=3.12, N=   8
#   • car_interior                   | V=4.40, A=3.00, N=  10
#   • castle                         | V=3.62, A=3.25, N=   8
#   • church_indoor                  | V=4.08, A=3.02, N=  40
#   • closet                         | V=4.33, A=3.00, N=   3
#   • coast                          | V=4.21, A=3.33, N=  39
#   • corn_field                     | V=3.50, A=3.25, N=  20
#   • desert_road                    | V=4.00, A=3.29, N=  14
#   • discotheque                    | V=3.76, A=3.26, N= 144
#   • escalator_indoor               | V=3.56, A=3.33, N=  18
#   • field_road                     | V=5.67, A=3.67, N=   3
#   • football_field                 | V=3.81, A=3.32, N= 641
#   • forest_broadleaf               | V=3.57, A=3.86, N=   7
#   • garage_indoor                  | V=6.00, A=4.00, N=   1
#   • hayfield                       | V=4.00, A=3.00, N=   1
#   • home_office                    | V=4.33, A=3.67, N=   3
#   • ice_floe                       | V=3.20, A=4.40, N=   5
#   • ice_shelf                      | V=3.40, A=3.60, N=   5
#   • igloo                          | V=4.09, A=3.64, N=  11
#   • inn_outdoor                    | V=6.00, A=6.00, N=   1
#   • lagoon                         | V=6.00, A=4.50, N=   2
#   • lake_natural                   | V=3.89, A=3.44, N=   9
#   • mansion                        | V=4.00, A=4.00, N=   1
#   • marsh                          | V=4.67, A=3.67, N=   3
#   • martial_arts_gym               | V=3.65, A=2.90, N= 407
#   • mausoleum                      | V=3.50, A=3.50, N=   4
#   • mountain_path                  | V=4.00, A=2.94, N=  16
#   • natural_history_museum         | V=4.40, A=3.40, N=   5
#   • ocean                          | V=3.58, A=3.72, N=  43
#   • orchard                        | V=4.08, A=3.02, N=  61
#   • orchestra_pit                  | V=3.69, A=3.03, N= 452
#   • pagoda                         | V=5.00, A=5.00, N=   1
#   • park                           | V=3.82, A=2.89, N= 626
#   • playground                     | V=3.66, A=3.10, N= 196
#   • pond                           | V=5.00, A=3.67, N=   3
#   • rice_paddy                     | V=3.92, A=2.92, N=  40
#   • ruin                           | V=3.33, A=5.00, N=   3
#   • sauna                          | V=4.43, A=3.43, N=   7
#   • science_museum                 | V=3.48, A=3.18, N=  60
#   • ski_slope                      | V=3.76, A=3.07, N=  29
#   • snowfield                      | V=4.00, A=3.50, N=   8
#   • soccer_field                   | V=3.95, A=3.05, N= 488
#   • stable                         | V=3.68, A=3.23, N=  22
#   • stadium_baseball               | V=3.72, A=2.93, N= 235
#   • stadium_football               | V=3.72, A=3.19, N=1433
#   • stadium_soccer                 | V=3.84, A=3.17, N= 862
#   • stage_indoor                   | V=4.01, A=2.92, N= 148
#   • staircase                      | V=3.69, A=3.50, N=  16
#   • toyshop                        | V=3.82, A=2.88, N=  33
#   • veterinarians_office           | V=3.83, A=2.95, N= 327
#   • village                        | V=3.51, A=3.23, N=  35
#   • vineyard                       | V=3.64, A=3.32, N=  28
#   • water_park                     | V=4.09, A=3.40, N=  65
#   • watering_hole                  | V=3.63, A=3.41, N=  27
#   • wheat_field                    | V=4.37, A=3.00, N=  30
#
#
# ================================================================================
# CLUSTER 3
# ================================================================================
# Center: Valence=2.61, Arousal=3.09
# Number of scenes: 51
# Total samples: 8653
#
# All scenes in this cluster:
# --------------------------------------------------------------------------------
#   • amphitheater                   | V=2.91, A=3.13, N= 127
#   • aqueduct                       | V=2.00, A=2.67, N=   3
#   • army_base                      | V=2.75, A=2.99, N=1598
#   • assembly_line                  | V=2.59, A=2.81, N= 140
#   • attic                          | V=1.67, A=3.00, N=   3
#   • auto_factory                   | V=1.50, A=2.93, N=  28
#   • basement                       | V=2.80, A=3.40, N=  25
#   • bazaar_outdoor                 | V=2.56, A=3.09, N= 693
#   • bullring                       | V=2.80, A=3.35, N= 105
#   • canal_natural                  | V=2.00, A=3.67, N=   3
#   • catacomb                       | V=2.00, A=4.50, N=   2
#   • cemetery                       | V=2.34, A=2.97, N=  32
#   • cockpit                        | V=3.00, A=4.09, N=  11
#   • courthouse                     | V=2.00, A=4.00, N=   1
#   • crevasse                       | V=2.00, A=2.89, N=   9
#   • crosswalk                      | V=2.60, A=2.85, N= 540
#   • desert_sand                    | V=2.14, A=4.86, N=   7
#   • embassy                        | V=2.76, A=2.79, N= 228
#   • fabric_store                   | V=2.82, A=3.12, N=  17
#   • fire_station                   | V=2.61, A=2.90, N= 165
#   • grotto                         | V=1.00, A=6.00, N=   1
#   • hangar_outdoor                 | V=2.40, A=2.60, N=  10
#   • heliport                       | V=2.20, A=2.60, N=   5
#   • hot_spring                     | V=1.95, A=3.74, N=  19
#   • jail_cell                      | V=2.64, A=3.07, N=  56
#   • junkyard                       | V=1.79, A=3.21, N=  28
#   • landfill                       | V=2.21, A=3.47, N= 368
#   • landing_deck                   | V=2.40, A=3.02, N=  62
#   • laundromat                     | V=2.60, A=3.00, N=   5
#   • library_outdoor                | V=1.00, A=1.00, N=   1
#   • lighthouse                     | V=2.00, A=2.00, N=   2
#   • lock_chamber                   | V=2.75, A=3.38, N=   8
#   • moat_water                     | V=2.00, A=3.67, N=   3
#   • mosque_outdoor                 | V=2.64, A=3.82, N=  11
#   • museum_outdoor                 | V=3.00, A=3.42, N=  12
#   • oilrig                         | V=1.00, A=4.00, N=   1
#   • plaza                          | V=2.48, A=3.19, N=1513
#   • racecourse                     | V=2.67, A=3.24, N= 412
#   • raceway                        | V=2.47, A=2.73, N=  51
#   • repair_shop                    | V=2.75, A=2.80, N=  61
#   • server_room                    | V=2.40, A=3.00, N=   5
#   • shoe_shop                      | V=2.38, A=3.48, N=  29
#   • shopping_mall_indoor           | V=1.00, A=3.00, N=   1
#   • slum                           | V=2.78, A=3.18, N=1136
#   • street                         | V=2.55, A=3.05, N= 977
#   • synagogue_outdoor              | V=2.57, A=2.86, N=   7
#   • trench                         | V=2.68, A=2.86, N= 116
#   • volcano                        | V=1.00, A=4.20, N=   5
#   • wave                           | V=2.00, A=3.71, N=   7
#   • wind_farm                      | V=2.00, A=3.00, N=   3
#   • windmill                       | V=0.00, A=5.00, N=   1
#
#
# ================================================================================
# CLUSTER 4
# ================================================================================
# Center: Valence=3.97, Arousal=2.60
# Number of scenes: 87
# Total samples: 7349
#
# All scenes in this cluster:
# --------------------------------------------------------------------------------
#   • alcove                         | V=4.00, A=1.00, N=   1
#   • apartment_building_outdoor     | V=4.00, A=2.50, N=   2
#   • arcade                         | V=4.20, A=2.20, N=   5
#   • archive                        | V=3.84, A=2.65, N=  49
#   • art_school                     | V=4.13, A=2.62, N=1022
#   • art_studio                     | V=3.87, A=2.56, N= 114
#   • artists_loft                   | V=3.77, A=2.15, N=  13
#   • balcony_exterior               | V=5.00, A=2.50, N=   2
#   • balcony_interior               | V=4.31, A=2.62, N=  29
#   • bamboo_forest                  | V=3.84, A=2.80, N=  25
#   • banquet_hall                   | V=3.86, A=2.60, N=  42
#   • beach_house                    | V=5.00, A=2.00, N=   1
#   • biology_laboratory             | V=3.84, A=2.58, N= 372
#   • boardwalk                      | V=3.80, A=2.67, N=  30
#   • bookstore                      | V=3.77, A=2.46, N=  35
#   • bowling_alley                  | V=4.80, A=2.40, N=   5
#   • cabin_outdoor                  | V=4.00, A=1.33, N=   3
#   • cafeteria                      | V=4.13, A=2.27, N= 110
#   • canyon                         | V=4.47, A=2.67, N=  15
#   • classroom                      | V=3.79, A=2.52, N=1413
#   • cliff                          | V=4.00, A=1.80, N=   5
#   • coffee_shop                    | V=4.06, A=2.83, N= 110
#   • computer_room                  | V=3.88, A=2.45, N=  40
#   • creek                          | V=4.62, A=2.50, N=   8
#   • delicatessen                   | V=4.60, A=2.40, N=   5
#   • dining_hall                    | V=4.30, A=2.30, N=  70
#   • dining_room                    | V=5.50, A=0.50, N=   2
#   • fire_escape                    | V=4.00, A=2.75, N=   4
#   • food_court                     | V=4.52, A=2.34, N=  29
#   • forest_path                    | V=4.46, A=2.69, N=  13
#   • fountain                       | V=3.89, A=2.82, N=  28
#   • galley                         | V=5.00, A=2.00, N=   5
#   • gazebo_exterior                | V=6.00, A=0.00, N=   1
#   • general_store_indoor           | V=5.00, A=1.00, N=   1
#   • gymnasium_indoor               | V=4.19, A=2.82, N=  96
#   • highway                        | V=3.86, A=2.14, N=   7
#   • hotel_room                     | V=4.00, A=2.63, N=  19
#   • hunting_lodge_outdoor          | V=4.00, A=2.00, N=   1
#   • ice_cream_parlor               | V=4.77, A=2.51, N=  35
#   • jacuzzi_indoor                 | V=4.67, A=2.67, N=   3
#   • japanese_garden                | V=5.00, A=1.00, N=   1
#   • kindergarden_classroom         | V=4.32, A=2.56, N= 288
#   • kitchen                        | V=4.91, A=2.55, N=  11
#   • lawn                           | V=3.97, A=2.28, N=  32
#   • library_indoor                 | V=3.92, A=2.37, N= 131
#   • market_indoor                  | V=3.83, A=2.00, N=  23
#   • mountain                       | V=4.43, A=2.79, N=  14
#   • mountain_snowy                 | V=3.82, A=2.64, N=  11
#   • nursery                        | V=3.90, A=2.75, N=  20
#   • nursing_home                   | V=3.89, A=2.73, N=1685
#   • oast_house                     | V=5.50, A=2.75, N=   4
#   • office_cubicles                | V=3.71, A=2.45, N=  49
#   • parking_garage_indoor          | V=4.00, A=2.00, N=   1
#   • pasture                        | V=4.40, A=2.00, N=   5
#   • patio                          | V=3.91, A=2.34, N=  32
#   • pavilion                       | V=4.38, A=1.62, N=   8
#   • pet_shop                       | V=4.00, A=1.67, N=   3
#   • pharmacy                       | V=3.73, A=2.00, N=  33
#   • phone_booth                    | V=3.67, A=2.67, N=   3
#   • picnic_area                    | V=4.10, A=2.58, N= 235
#   • playroom                       | V=3.91, A=2.74, N=  23
#   • porch                          | V=4.04, A=2.51, N=  45
#   • rainforest                     | V=4.10, A=2.87, N=  30
#   • recreation_room                | V=4.16, A=2.41, N=  37
#   • residential_neighborhood       | V=4.00, A=2.50, N=   2
#   • restaurant                     | V=3.92, A=2.58, N=  80
#   • restaurant_patio               | V=3.79, A=1.96, N=  24
#   • rock_arch                      | V=4.00, A=2.75, N=   4
#   • rope_bridge                    | V=3.79, A=2.69, N=  39
#   • sandbox                        | V=3.85, A=2.73, N= 342
#   • shed                           | V=5.00, A=2.00, N=   1
#   • supermarket                    | V=3.88, A=2.16, N=  25
#   • swimming_hole                  | V=3.91, A=2.82, N=  22
#   • swimming_pool_indoor           | V=4.50, A=2.67, N=   6
#   • swimming_pool_outdoor          | V=5.12, A=2.75, N=   8
#   • television_room                | V=4.33, A=1.67, N=   3
#   • temple_asia                    | V=4.00, A=2.50, N=   2
#   • ticket_booth                   | V=4.17, A=1.83, N=   6
#   • train_station_platform         | V=4.11, A=2.78, N=   9
#   • tundra                         | V=4.17, A=2.75, N=  12
#   • underwater_ocean_deep          | V=4.00, A=2.50, N=   2
#   • valley                         | V=4.20, A=2.40, N=   5
#   • vegetable_garden               | V=4.10, A=2.10, N=  20
#   • volleyball_court_outdoor       | V=4.18, A=2.87, N=  87
#   • waiting_room                   | V=3.91, A=2.70, N= 140
#   • yard                           | V=4.40, A=2.47, N=  15
#   • zen_garden                     | V=5.00, A=1.00, N=   1
# Cluster 0 (Cluster 0): 75 scenes
# Cluster 1 (Cluster 1): 64 scenes
# Cluster 2 (Cluster 2): 77 scenes
# Cluster 3 (Cluster 3): 55 scenes
# Cluster 4 (Cluster 4): 94 scenes
#
# scene_clusters_5.xlsx saved to: c:\Users\jarne\Documents\Code Masterthesis\nsai_social_cognition\data\scene_clusters_5.xlsx

# %%
cluster_centers
# Out:
# array([[3.36149011, 2.5601717 ],
#        [3.27939812, 2.91744821],
#        [3.85022913, 3.11970493],
#        [2.60672599, 3.09372472],
#        [3.96652606, 2.5983127 ]])

# %%
def remove_brackets(lst):  
    return ', '.join(lst)

# %%
class FacePredictionsDataset(DPLDataset):
    def __init__(self, indices, feature_dir):
        self.indices = indices
        self.feature_dir = feature_dir

    def __getitem__(self, idx):
        if isinstance(idx, (tuple, list)):
            idx = idx[0]
        if isinstance(idx, Constant):
            idx = int(idx.value)

        face_rows = df_boxes[df_boxes['index'] == idx].sort_values('face_rank')
        face_features_list = []
        for _, box_row in face_rows.iterrows():
            face_rank = int(box_row['face_rank'])
            face_prediction_file = os.path.join(self.feature_dir, "faces", f"face_{idx}_{face_rank}.pt")
            face_features = torch.load(face_prediction_file, map_location="cpu")  # 
            face_features_list.append(face_features)

        if len(face_features_list) == 0:
            face_avg = torch.zeros(7, dtype=torch.float32)
        else:
            face_avg = torch.stack(face_features_list).mean(dim=0)

        return face_avg
    
    def __len__(self):
        return len(self.indices)
    
    def to_query(self, i):
        pass

face_predictions = FacePredictionsDataset(indices, os.path.join(data_dir, "pretrained_logits"))

# %%
# laod fer val aro stats from csv
fer_val_aro_df = pd.read_csv(os.path.join(data_dir, "fer_val_aro_stats.csv"))
fer_val_aro_df.head()
# Out:
#    emotion  count  avg_valence  avg_arousal
# 0    angry   4335     2.786390     2.992157
# 1  disgust      2     4.000000     3.500000
# 2     fear    588     2.928571     2.782313
# 3    happy   6675     4.675955     2.981873
# 4  neutral   4791     3.240660     2.631392

# %%
# read the csv file from the data folder
categories_365_path = os.path.join(data_dir, "scene_clusters_5.xlsx")

# read as csv
categories_365_df = pd.read_excel(categories_365_path)
categories_365_df.head()
# Out:
#           Cluster 0                 Cluster 1               Cluster 2  \
# 0  airport_terminal            airplane_cabin                airfield
# 1             alley            amusement_park        amusement_arcade
# 2          aquarium  archaelogical_excavation                    arch
# 3       arena_rodeo              arena_hockey       arena_performance
# 4       art_gallery                auditorium  athletic_field_outdoor
#
#        Cluster 3                   Cluster 4
# 0   amphitheater                      alcove
# 1       aqueduct  apartment_building_outdoor
# 2      army_base                      arcade
# 3  assembly_line                     archive
# 4          attic                  art_school

# %%
# From the dataframe, create a dictionary that maps every category to its broader category (column where it belongs)
category_mapping = {}
for col in categories_365_df.columns:
    for category in categories_365_df[col].dropna().tolist():
        category_mapping[category] = col

mapped_categories = list(dict.fromkeys(category_mapping.values()))
print("Mapped Categories:", mapped_categories)
# Out:
# Mapped Categories: ['Cluster 0', 'Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4']

# %%
# Check for all the columns in the excel (without the first row) if there are no duplicates and the length is 365
cats = []
for col in categories_365_df.columns:
    unique_cats = categories_365_df[col].dropna().tolist()
    cats.extend(unique_cats)
unique_set = set(cats)
print("Total unique categories mapped:", len(unique_set))  # Should be 365
# Out:
# Total unique categories mapped: 365

# %%
errors = 0
# Check if all the 365 categories are in the mapping
for cat in scene_categories:
    if cat not in category_mapping:
        print("Category not found in mapping:", cat)
        errors += 1

# check if all keys in category_mapping are in scene_categories
for cat in category_mapping.keys():
    if cat not in scene_categories:
        print("Category in mapping not found in scene categories:", cat)
        errors += 1

assert(errors == 0)

# %%
# Build mapping matrix with deterministic column order and float dtype
map_365 = torch.zeros((365, len(mapped_categories)), dtype=torch.float32)
for i, cat in enumerate(scene_categories):
    coarse = category_mapping[cat]
    coarse_idx = mapped_categories.index(coarse)
    map_365[i, coarse_idx] = 1.0

# %%
def get_mapped_category(scene_idx_365):
    # print the name of the 365 category
    mapped = map_365[scene_idx_365]
    mapped_idx = torch.argmax(mapped).item()
    print(scene_categories[scene_idx_365], "->", mapped_categories[mapped_idx])

# %%
class SceneNet(nn.Module):
    def __init__(self, map_365=map_365):
        super().__init__()
        self.register_buffer("map_365", map_365.clone().float())
        # Learnable temperature for scene logits
        self.temp = nn.Parameter(torch.tensor(1.0))

    def forward(self, logits_365):
        """
        logits_365: (batch, 365) raw logits from pretrained ResNet18
        Returns: (batch, 5) probabilities over scene clusters
        """
        if isinstance(logits_365, list):
            logits_365 = torch.stack(logits_365)
        
        logits_365 = logits_365.to(self.temp.device)
        
        # Softmax over 365 categories with temperature
        probs_365 = torch.softmax(logits_365 * self.temp, dim=-1)  # (batch, 365)
        
        # Map to 5 clusters
        mapped_probs = torch.matmul(probs_365, self.map_365)  # (batch, 5)
        
        return mapped_probs

scene_model_torch = SceneNet()
scene_network = Network(scene_model_torch, "scene_model", batching=True)
scene_network.optimizer = optim.Adam(scene_model_torch.parameters(), lr=0.001)

# %%
# Maybe precalculate these again with blurred faces in scenes folder of pretrained_logits
class ScenePredictionsDataset(DPLDataset):
    def __init__(self, indices, feature_dir):
        self.indices = indices
        self.feature_dir = feature_dir

    def __getitem__(self, idx):
        if isinstance(idx, (tuple, list)):
            idx = idx[0]
        if isinstance(idx, Constant):
            idx = int(idx.value)

        scene_prediction_file = os.path.join(self.feature_dir, "scenes", f"scene_{idx}.pt")
        scene_features = torch.load(scene_prediction_file, map_location="cpu") 

        return scene_features
    
    def __len__(self):
        return len(self.indices)
    
    def to_query(self, i):
        pass

scene_predictions = ScenePredictionsDataset(indices, os.path.join(data_dir, "pretrained_logits"))

# %%
class FacesDataset(ImageDataset):
    def __init__(self, indices):
        super().__init__(os.path.join(findingemo_dir, "faces"), extension="jpg", transform=emotion_transform)
        self.indices = indices
    
    def __getitem__(self, i):
        if isinstance(i, tuple):
            i = tuple(int(x.value) if isinstance(x, Constant) else x for x in i)
        
        tensor = super().__getitem__("img_{}_face_{}".format(*i))
        return tensor['pixel_values'][0]
    
    def __len__(self):
        return len(self.indices)
    
    def to_query(self, i):
        pass
    
faces_dataset = FacesDataset(indices)

# %%
class FaceNet(nn.Module):
    def __init__(self):
        super().__init__()
        # Learnable temperature for 7 FER classes
        self.temp = nn.Parameter(torch.tensor(1.0))

    def forward(self, logits_7):
        """
        logits_7: (batch, 7) raw logits from pretrained ViT face expression model
        Returns: (batch, 7) probabilities over FER classes
        """
        if isinstance(logits_7, list):
            logits_7 = torch.stack(logits_7)
        
        logits_7 = logits_7.to(next(self.parameters()).device)
        
        # Softmax with temperature
        probs = torch.softmax(logits_7 * self.temp, dim=-1)  # (batch, 7)
        
        return probs

face_model_torch = FaceNet()
face_network = Network(face_model_torch, "face_model", batching=True)
face_network.optimizer = optim.Adam(face_model_torch.parameters(), lr=0.001)

# %%
def show_pretrained_model_predictions_on_sample(sample_idx):
    row = df.iloc[sample_idx]
    img_path = os.path.join(findingemo_dir, row['image_path'])
    img = Image.open(img_path).convert("RGB")
    
    # Convert to numpy array for drawing
    img_array = np.array(img)
    
    # Get all face boxes for this image
    face_boxes = df_boxes[df_boxes['index'] == sample_idx].sort_values('face_rank')
    
    # Draw bounding boxes and predictions on the image
    for _, box_row in face_boxes.iterrows():
        x1, y1, x2, y2 = int(box_row['x1']), int(box_row['y1']), int(box_row['x2']), int(box_row['y2'])
        face_rank = int(box_row['face_rank'])
        
        model_output = torch.load(os.path.join(data_dir, "pretrained_logits", "faces", f"face_{sample_idx}_{face_rank}.pt")).to(DEVICE).unsqueeze(0)
        probs_output = torch.softmax(model_output, dim=1)
        probs = probs_output[0].cpu().detach().numpy()
        
        # Get top prediction
        top_idx = np.argmax(probs)
        top_label = f"{fer_classes[top_idx]}: {probs[top_idx]:.2f}"
        
        # Draw rectangle
        cv2.rectangle(img_array, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
        # Calculate text size for better positioning
        font = cv2.FONT_HERSHEY_SIMPLEX
        font_scale = 0.8
        thickness = 2
        (text_width, text_height), baseline = cv2.getTextSize(top_label, font, font_scale, thickness)
        
        # Position text above the box if there's space, otherwise below
        if y1 - text_height - 10 > 0:
            text_y = y1 - 10
        else:
            text_y = y2 + text_height + 10
        
        # Draw text with background for better visibility
        cv2.rectangle(img_array, (x1, text_y - text_height - 5), 
                    (x1 + text_width + 5, text_y + 5), (0, 255, 0), -1)
        cv2.putText(img_array, top_label, (x1, text_y), 
                    font, font_scale, (0, 0, 0), thickness)
        
    # Display image with bounding boxes and predictions
    plt.figure(figsize=(15, 10))
    plt.imshow(img_array)
    plt.axis('off')
    plt.title(f"Image Index: {sample_idx}, Valence: {row['valence']}, Arousal: {row['arousal']}, Emotion: {row['emotion']}", fontsize=16)
    plt.show()

    scene_logits = torch.load(os.path.join(data_dir, "pretrained_logits", "scenes", f"scene_{sample_idx}.pt")).to(DEVICE)
   
    # Show top 3 from base model (365 categories)
    top3_base = torch.topk(scene_logits, 3)
    print("Base model (365 categories):")
    for prob, idx in zip(top3_base.values.cpu(), top3_base.indices.cpu()):
        idx_int = int(idx.item())  # Convert tensor to Python int
        print(f"  {get_category_name(idx_int)}: {prob:.4f}")
    print("")
    
    # Map to 5 clusters
    scene_logits_unsqueezed = scene_logits.unsqueeze(0)  # (1, 365)
    probs_365 = torch.softmax(scene_logits_unsqueezed, dim=1)  # (1, 365)
    mapped_probs = torch.matmul(probs_365, map_365.to(DEVICE))  # (1, 5)
    mapped_probs = mapped_probs[0].cpu()  # (5,)
    
    # Show mapped cluster probabilities
    top3_mapped = torch.topk(mapped_probs, 3)
    print("Mapped to 5 clusters:")
    for prob, idx in zip(top3_mapped.values, top3_mapped.indices):
        cluster_name = mapped_categories[int(idx.item())]
        print(f"  {cluster_name}: {prob:.4f}")
    print("")

# %%
show_pretrained_model_predictions_on_sample(10)
# Out:
# Base model (365 categories):
#   biology_laboratory: 11.2777
#   auditorium: 10.6377
#   martial_arts_gym: 10.5785
#
# Mapped to 5 clusters:
#   Cluster 4: 0.3867
#   Cluster 0: 0.2784
#   Cluster 1: 0.1825

# %%
cluster_centers
# Out:
# array([[3.36149011, 2.5601717 ],
#        [3.27939812, 2.91744821],
#        [3.85022913, 3.11970493],
#        [2.60672599, 3.09372472],
#        [3.96652606, 2.5983127 ]])

# %%
# Create the prolog file
prolog_file_name = "model8.pl"
prolog_file_path = os.path.join(prolog_dir, prolog_file_name)
with open(prolog_file_path, "w") as f:

    f.write("nn(face_model, [Face], Emotion,\n")
    f.write("   [angry, disgust, fear, happy, neutral, sad, surprise]) ::\n")
    f.write("   face_emotion(Face, Emotion).\n\n")

    f.write(f"nn(scene_model, [ScenePredictions], Cluster, [{remove_brackets(list(range(5)))}]) ::\n")
    f.write("   scene(ScenePredictions, Cluster).\n\n")

    f.write(f"nn(va_to_emotion_model, [FaceFeat, SceneFeat, CV, CA], Emotion,\n")
    f.write(f"   [{remove_brackets(list(fe_labels))}]) ::\n")
    f.write("   va_to_emotion(FaceFeat, SceneFeat, CV, CA, Emotion).\n\n")

    for scene, row, in scene_priors.iterrows():
        if not (np.isnan(row['valence']) or np.isnan(row['arousal'])):
            f.write(f"scene_prior({scene}, {round(row['valence'], 2)}, {round(row['arousal'], 2)}).\n")
        else:
            # allocate random values for valence and arousal between 0 and 6
            valence = round(random.uniform(0, 6), 2)
            arousal = round(random.uniform(0, 6), 2)
            f.write(f"scene_prior({scene}, {valence}, {arousal}).\n")

    # Next step model these with gaussian distribution so we don't always have fixed values, maybe also for the scene priors
    f.write("\n")
    f.write("face_prior(angry, 1.2, 5.1).\n")
    f.write("face_prior(disgust, 0.9, 3.1).\n")
    f.write("face_prior(fear, 0.6, 5.4).\n")
    f.write("face_prior(happy, 5.4, 4.8).\n")
    f.write("face_prior(neutral, 3.0, 2.4).\n")
    f.write("face_prior(sad, 0.9, 1.5).\n")
    f.write("face_prior(surprise, 3.3, 5.4).\n")
    f.write("\n")

    f.write("small_diff(F, S)  :- abs(F - S) =< 1.\n")
    f.write("medium_diff(F, S) :- D is abs(F - S), D > 1, D =< 3.\n")
    f.write("large_diff(F, S)  :- abs(F - S) > 3.\n")

    f.write("\n")
    f.write(f"t(_) :: use_face_small_val(F,S) ; t(_) :: use_scene_small_val(F,S).\n")
    f.write(f"t(_) :: use_face_small_aro(F,S) ; t(_) :: use_scene_small_aro(F,S).\n")
    f.write(f"t(_) :: use_face_big_val(F,S) ; t(_) :: use_scene_big_val(F,S).\n")
    f.write(f"t(_) :: use_face_big_aro(F,S) ; t(_) :: use_scene_big_aro(F,S).\n")
    f.write("\n")

    f.write("combine_val(FV, SV, FV) :-\n")
    f.write("    small_diff(FV, SV), \n")
    f.write("    use_face_small_val(FV, SV). \n")
    f.write("\n")
    f.write("combine_val(FV, SV, SV) :-\n")
    f.write("    small_diff(FV, SV), \n")
    f.write("    use_scene_small_val(FV, SV). \n")
    f.write("\n")
    f.write("combine_val(F, S, M) :-\n")
    f.write("    medium_diff(F, S), \n")
    f.write("    M is (2*F + S) / 3. \n")
    f.write("\n")
    f.write("combine_val(FV, SV, FV) :-\n")
    f.write("    large_diff(FV, SV), \n")
    f.write("    use_face_big_val(FV, SV). \n")
    f.write("\n")
    f.write("combine_val(FV, SV, SV) :-\n")
    f.write("    large_diff(FV, SV), \n")
    f.write("    use_scene_big_val(FV, SV). \n")
    f.write("\n")

    f.write("combine_aro(FA, SA, FA) :-\n")
    f.write("    small_diff(FA, SA), \n")
    f.write("    use_face_small_aro(FA, SA). \n")
    f.write("\n")
    f.write("combine_aro(FA, SA, SA) :-\n")
    f.write("    small_diff(FA, SA), \n")
    f.write("    use_scene_small_aro(FA, SA). \n")
    f.write("\n")
    f.write("combine_aro(F, S, M) :-\n")
    f.write("    medium_diff(F, S), \n")
    f.write("    M is (2*F + S) / 3. \n")
    f.write("\n")
    f.write("combine_aro(FA, SA, FA) :-\n")
    f.write("    large_diff(FA, SA), \n")
    f.write("    use_face_big_aro(FA, SA). \n")
    f.write("\n")
    f.write("combine_aro(FA, SA, SA) :-\n")
    f.write("    large_diff(FA, SA), \n")
    f.write("    use_scene_big_aro(FA, SA). \n")
    f.write("\n")
    
    f.write("final_emotion(FacePredictions, ScenePredictions, FaceFeat, SceneFeat, Emotion) :-\n")
    f.write("    face_emotion(FacePredictions, FaceEmotion),\n")
    f.write("    face_prior(FaceEmotion, FV, FA),\n")
    f.write("    scene(ScenePredictions, Scene),\n")
    f.write("    scene_prior(Scene, SV, SA),\n")
    f.write("    combine_val(FV, SV, CV),\n")
    f.write("    combine_aro(FA, SA, CA),\n")
    f.write("    va_to_emotion(FaceFeat, SceneFeat, CV, CA, Emotion). \n")
    f.write("\n")

    f.write("test_va(FacePredictions, ScenePredictions, FV, FA, SV, SA) :-\n")
    f.write("    face_emotion(FacePredictions, FaceEmotion),\n")
    f.write("    face_prior(FaceEmotion, FV, FA),\n")
    f.write("    scene(ScenePredictions, Scene),\n")
    f.write("    scene_prior(Scene, SV, SA).\n")
    f.write("\n")
    
    f.write("test_combo(FacePredictions, ScenePredictions, CV, CA) :-\n")
    f.write("    face_emotion(FacePredictions, FaceEmotion),\n")
    f.write("    face_prior(FaceEmotion, FV, FA),\n")
    f.write("    scene(ScenePredictions, Scene),\n")
    f.write("    scene_prior(Scene, SV, SA),\n")
    f.write("    combine_val(FV, SV, CV),\n")
    f.write("    combine_aro(FA, SA, CA).\n")
    f.write("\n")

print("Prolog file written to:", prolog_file_path)
# Out:
# Prolog file written to: c:\Users\jarne\Documents\Code Masterthesis\nsai_social_cognition\code\prolog\model8.pl

# %%
class FacePredictionsDataset(DPLDataset):
    def __init__(self, indices, feature_dir):
        self.indices = indices
        self.feature_dir = feature_dir

    def __getitem__(self, idx):
        if isinstance(idx, (tuple, list)):
            idx = idx[0]
        if isinstance(idx, Constant):
            idx = int(idx.value)

        face_rows = df_boxes[df_boxes['index'] == idx].sort_values('face_rank')
        face_features_list = []
        for _, box_row in face_rows.iterrows():
            face_rank = int(box_row['face_rank'])
            face_prediction_file = os.path.join(self.feature_dir, "faces", f"face_{idx}_{face_rank}.pt")
            face_features = torch.load(face_prediction_file, map_location="cpu")  # 
            face_features_list.append(face_features)

        if len(face_features_list) == 0:
            face_avg = torch.zeros(7, dtype=torch.float32)
        else:
            face_avg = torch.stack(face_features_list).mean(dim=0)

        return face_avg
    
    def __len__(self):
        return len(self.indices)
    
    def to_query(self, i):
        pass

face_predictions = FacePredictionsDataset(indices, os.path.join(data_dir, "pretrained_logits"))

# %%
# Maybe precalculate these again with blurred faces in scenes folder of pretrained_logits
class ScenePredictionsDataset(DPLDataset):
    def __init__(self, indices, feature_dir):
        self.indices = indices
        self.feature_dir = feature_dir

    def __getitem__(self, idx):
        if isinstance(idx, (tuple, list)):
            idx = idx[0]
        if isinstance(idx, Constant):
            idx = int(idx.value)

        scene_prediction_file = os.path.join(self.feature_dir, "scenes", f"scene_{idx}.pt")
        scene_features = torch.load(scene_prediction_file, map_location="cpu") 

        return scene_features
    
    def __len__(self):
        return len(self.indices)
    
    def to_query(self, i):
        pass

scene_predictions = ScenePredictionsDataset(indices, os.path.join(data_dir, "pretrained_logits"))

# %%
class FaceNet(nn.Module):
    def __init__(self):
        super().__init__()
        # Learnable temperature so outputs require grad
        self.temp = nn.Parameter(torch.tensor(1.0))

    def forward(self, tensor):
        """
        Load all face logits for an image, average logits across faces, then softmax once.
        """
        device = self.temp.device
        tensor = tensor.to(device)
        probs = torch.softmax(tensor * self.temp, dim=-1)           # (num_classes,)
        return probs

# %%
face_model_torch = FaceNet()
face_network = Network(face_model_torch, "face_model", batching=True)
face_network.optimizer = optim.Adam(face_model_torch.parameters(), lr=0.001)

# %%
class SceneNet(nn.Module):
    def __init__(self):
        super().__init__()
        # Learnable temperature so outputs require grad
        self.temp = nn.Parameter(torch.tensor(1.0))
    def forward(self, tensor):
        """
        Load all face logits for an image, average logits across faces, then softmax once.
        """
        device = self.temp.device
        tensor = tensor.to(device)
        probs = torch.softmax(tensor * self.temp, dim=-1)           # (num_classes,)
        return probs

# %%
scene_model_torch = SceneNet()
scene_network = Network(scene_model_torch, "scene_model", batching=True)
scene_network.optimizer = optim.Adam(scene_model_torch.parameters(), lr=0.001)

# %%
LABEL_TO_ID = {emo: i for i, emo in enumerate(fe_labels)}
print("LABEL_TO_ID:", LABEL_TO_ID)
# Out:
# LABEL_TO_ID: {'anger': 0, 'anticipation': 1, 'disgust': 2, 'fear': 3, 'joy': 4, 'sadness': 5, 'surprise': 6, 'trust': 7}

# %%
from deepproblog.utils.confusion_matrix import ConfusionMatrix

from sklearn.metrics import confusion_matrix as sklearn_cm, precision_recall_fscore_support

def evaluate_dpl_with_metrics(model, dataset):
    """Enhanced DPL evaluate function that returns detailed metrics"""
    from deepproblog.utils.confusion_matrix import ConfusionMatrix
    
    confusion_matrix = ConfusionMatrix()
    model.eval()
    
    all_labels = []
    all_preds = []
    
    for i, gt_query in enumerate(tqdm(dataset.to_queries(), desc="Evaluating DPL", leave=False)):
        test_query = gt_query.variable_output()
        answer = model.solve([test_query])[0]
        actual = str(gt_query.output_values()[0])
        
        if len(answer.result) == 0:
            predicted = "no_answer"
        else:
            max_ans = max(answer.result, key=lambda x: answer.result[x])
            p = answer.result[max_ans]
            predicted = str(max_ans.args[gt_query.output_ind[0]])
        
        confusion_matrix.add_item(predicted, actual)
        all_labels.append(actual)
        all_preds.append(predicted)
    
    # Convert emotion labels to indices
    label_to_idx = {emo: i for i, emo in enumerate(fe_labels)}
    y_true = np.array([label_to_idx.get(label, -1) for label in all_labels])
    y_pred = np.array([label_to_idx.get(pred, -1) for pred in all_preds])
    
    # Remove any "no_answer" predictions (-1)
    valid_mask = (y_true >= 0) & (y_pred >= 0)
    y_true = y_true[valid_mask]
    y_pred = y_pred[valid_mask]
    
    # Calculate sklearn confusion matrix
    cm = sklearn_cm(y_true, y_pred, labels=range(len(fe_labels)))
    
    # Per-class metrics
    precision, recall, f1, support = precision_recall_fscore_support(
        y_true, y_pred, average=None, labels=range(len(fe_labels)), zero_division=0
    )
    
    # Overall accuracy
    accuracy = confusion_matrix.accuracy()
    result =  {
        'accuracy': accuracy,
        'confusion_matrix': cm,
        'dpl_confusion_matrix': confusion_matrix,
        'y_true': y_true,
        'y_pred': y_pred,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'support': support
    }
    print_dpl_detailed_metrics(result, fe_labels)

    model.train()
    return result


def print_dpl_detailed_metrics(results, label_names):
    """Print detailed metrics for DPL results"""
    print(f"\n{'='*70}")
    print(f"Overall Metrics:")
    print(f"{'='*70}")
    print(f"Accuracy: {results['accuracy']:.4f}")
    
    print(f"\n{'='*70}")
    print(f"Per-Class Metrics:")
    print(f"{'='*70}")
    print(f"{'Emotion':<15} {'Precision':<12} {'Recall':<12} {'F1-Score':<12} {'Support':<10}")
    print(f"{'-'*70}")
    
    for i, label in enumerate(label_names):
        print(f"{label:<15} {results['precision'][i]:<12.4f} "
              f"{results['recall'][i]:<12.4f} {results['f1'][i]:<12.4f} "
              f"{int(results['support'][i]):<10}")
    
    # Macro averages
    print(f"{'-'*70}")
    print(f"{'Macro Avg':<15} {results['precision'].mean():<12.4f} "
          f"{results['recall'].mean():<12.4f} {results['f1'].mean():<12.4f} "
          f"{int(results['support'].sum()):<10}")
    
    # Weighted averages
    weights = results['support'] / results['support'].sum()
    weighted_precision = (results['precision'] * weights).sum()
    weighted_recall = (results['recall'] * weights).sum()
    weighted_f1 = (results['f1'] * weights).sum()
    
    print(f"{'Weighted Avg':<15} {weighted_precision:<12.4f} "
          f"{weighted_recall:<12.4f} {weighted_f1:<12.4f} "
          f"{int(results['support'].sum()):<10}")

# %%
class FaceFeatureDataset(DPLDataset):
    def __init__(self, indices, feature_dir):
        self.indices = indices
        self.feature_dir = feature_dir

    def __getitem__(self, idx):
        if isinstance(idx, (tuple, list)):
            idx = idx[0]
        if isinstance(idx, Constant):
            idx = int(idx.value)

        # Load all face backbone features (768 each), average; if none, use neutral
        face_rows = df_boxes[df_boxes['index'] == idx].sort_values('face_rank')
        face_features_list = []
        for _, box_row in face_rows.iterrows():
            face_rank = int(box_row['face_rank'])
            face_prediction_file = os.path.join(self.feature_dir, "faces", f"face_{idx}_{face_rank}.pt")
            face_features = torch.load(face_prediction_file, map_location="cpu")  # 
            face_features_list.append(face_features)

        if len(face_features_list) == 0:
            face_avg = torch.zeros(768, dtype=torch.float32)
        else:
            face_avg = torch.stack(face_features_list).mean(dim=0)  # (768,)

        return face_avg
    
    def __len__(self):
        return len(self.indices)
    
    def to_query(self, i):
        pass

face_features = FaceFeatureDataset(indices, os.path.join(data_dir, "pretrained_backbone"))

# %%
class SceneFeatureDataset(DPLDataset):
    def __init__(self, indices, feature_dir):
        self.indices = indices
        self.feature_dir = feature_dir

    def __getitem__(self, idx):
        if isinstance(idx, (tuple, list)):
            idx = idx[0]
        if isinstance(idx, Constant):
            idx = int(idx.value)

        scene_prediction_file = os.path.join(self.feature_dir, "scenes", f"scene_{idx}.pt")
        scene_features = torch.load(scene_prediction_file, map_location="cpu")  # (512,)

        return scene_features
    
    def __len__(self):
        return len(self.indices)
    
    def to_query(self, i):
        pass

scene_features = SceneFeatureDataset(indices, os.path.join(data_dir, "pretrained_backbone"))

# %%
class HybridEmotionModel(nn.Module):
    def __init__(self):
        super().__init__()

        # ---- FEATURE PROJECTION ----
        self.face_proj = nn.Sequential(
            nn.Linear(768, 256),
            nn.ReLU(),
            nn.LayerNorm(256)
        )

        self.scene_proj = nn.Sequential(
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.LayerNorm(256)
        )

        # Final input dim = 256(face) + 256(scene) + 2(VA)
        self.classifier = nn.Sequential(
            nn.Linear(514, 512),
            nn.ReLU(),
            nn.LayerNorm(512),
            nn.Dropout(0.3),

            nn.Linear(512, 256),
            nn.ReLU(),
            nn.LayerNorm(256),
            nn.Dropout(0.3),

            nn.Linear(256, 128),
            nn.ReLU(),

            nn.Linear(128, 8),   # 8 emotion classes
            nn.Softmax(dim=1)
        )

    def forward(self, face_feat, scene_feat, cv, ca):
        """
        face_feat:  (batch, 768) or (768,)
        scene_feat: (batch, 512) or (512,)
        cv, ca:     (batch, 1) or scalar
        """
        device = next(self.parameters()).device

        face_feat = torch.as_tensor(face_feat, device=device, dtype=torch.float32)
        scene_feat = torch.as_tensor(scene_feat, device=device, dtype=torch.float32)
        cv = torch.as_tensor(cv, device=device, dtype=torch.float32)
        ca = torch.as_tensor(ca, device=device, dtype=torch.float32)

        if face_feat.dim() == 1:
            face_feat = face_feat.unsqueeze(0)
        if scene_feat.dim() == 1:
            scene_feat = scene_feat.unsqueeze(0)
        if cv.dim() == 0:
            cv = cv.unsqueeze(0)
        if ca.dim() == 0:
            ca = ca.unsqueeze(0)

        # Ensure 2D shapes
        face_feat = face_feat.view(face_feat.size(0), -1)
        scene_feat = scene_feat.view(scene_feat.size(0), -1)
        cv = cv.view(cv.shape[0], 1)
        ca = ca.view(ca.shape[0], 1)

        face_z = self.face_proj(face_feat)
        scene_z = self.scene_proj(scene_feat)
        va = torch.cat([cv, ca], dim=1)  # (batch, 2)
        x = torch.cat([face_z, scene_z, va], dim=1)
        logits = self.classifier(x)
        return logits

hybrid_emotion_model = HybridEmotionModel()
hybrid_emotion_model.to(DEVICE)
hybrid_emotion_network = Network(hybrid_emotion_model, "va_to_emotion_model", batching=True)
hybrid_emotion_network.optimizer = optim.Adam(hybrid_emotion_model.parameters(), lr=0.001)

# %%
def show_pretrained_model_predictions_on_sample(sample_idx):
    row = df.iloc[sample_idx]
    img_path = os.path.join(findingemo_dir, row['image_path'])
    img = Image.open(img_path).convert("RGB")
    
    # Convert to numpy array for drawing
    img_array = np.array(img)
    
    # Get all face boxes for this image
    face_boxes = df_boxes[df_boxes['index'] == sample_idx].sort_values('face_rank')
    
    # Draw bounding boxes and predictions on the image
    for _, box_row in face_boxes.iterrows():
        x1, y1, x2, y2 = int(box_row['x1']), int(box_row['y1']), int(box_row['x2']), int(box_row['y2'])
        face_rank = int(box_row['face_rank'])
        
        model_output = torch.load(os.path.join(data_dir, "pretrained_logits", "faces", f"face_{sample_idx}_{face_rank}.pt")).to(DEVICE).unsqueeze(0)
        probs_output = torch.softmax(model_output, dim=1)
        probs = probs_output[0].cpu().detach().numpy()
        
        # Get top prediction
        top_idx = np.argmax(probs)
        top_label = f"{fer_classes[top_idx]}: {probs[top_idx]:.2f}"
        
        # Draw rectangle
        cv2.rectangle(img_array, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
        # Calculate text size for better positioning
        font = cv2.FONT_HERSHEY_SIMPLEX
        font_scale = 0.8
        thickness = 2
        (text_width, text_height), baseline = cv2.getTextSize(top_label, font, font_scale, thickness)
        
        # Position text above the box if there's space, otherwise below
        if y1 - text_height - 10 > 0:
            text_y = y1 - 10
        else:
            text_y = y2 + text_height + 10
        
        # Draw text with background for better visibility
        cv2.rectangle(img_array, (x1, text_y - text_height - 5), 
                    (x1 + text_width + 5, text_y + 5), (0, 255, 0), -1)
        cv2.putText(img_array, top_label, (x1, text_y), 
                    font, font_scale, (0, 0, 0), thickness)
        
    # Display image with bounding boxes and predictions
    plt.figure(figsize=(15, 10))
    plt.imshow(img_array)
    plt.axis('off')
    plt.title(f"Image Index: {sample_idx}, Valence: {row['valence']}, Arousal: {row['arousal']}, Emotion: {row['emotion']}", fontsize=16)
    plt.show()

    scene_logits = torch.load(os.path.join(data_dir, "pretrained_logits", "scenes", f"scene_{sample_idx}.pt")).to(DEVICE)
    scene_probs = torch.softmax(scene_logits, dim=0)
   

    # Show top 3 from base model (365 categories)
    top3_base = torch.topk(scene_probs, 3)
    print("Base model (365 categories):")
    for prob, idx in zip(top3_base.values.cpu(), top3_base.indices.cpu()):
        print(f"  {get_category_name(idx)}: {prob:.4f}")
    print("")

# %%
random_sample_idx = random.randint(0, len(df) - 1)
show_pretrained_model_predictions_on_sample(random_sample_idx)
# Out:
# Base model (365 categories):
#   hospital_room: 0.2227
#   nursing_home: 0.1719
#   office: 0.0816

# %%
df[df.index == random_sample_idx]
# Out:
#                                               image_path       tags     age  \
# 17658  Run_2/Discontent elderly classroom/safety_cult...  Undefined  Adults
#
#        valence  arousal       emotion dec_factors  ambiguity  nr_faces
# 17658        1        0  anticipation     Context          0         5

# %%
from deepproblog.utils.confusion_matrix import ConfusionMatrix

from sklearn.metrics import confusion_matrix as sklearn_cm, precision_recall_fscore_support

def evaluate_dpl_with_metrics(model, dataset):
    """Enhanced DPL evaluate function that returns detailed metrics"""
    from deepproblog.utils.confusion_matrix import ConfusionMatrix
    
    confusion_matrix = ConfusionMatrix()
    model.eval()
    
    all_labels = []
    all_preds = []
    
    for i, gt_query in enumerate(tqdm(dataset.to_queries(), desc="Evaluating DPL", leave=False)):
        test_query = gt_query.variable_output()
        answer = model.solve([test_query])[0]
        actual = str(gt_query.output_values()[0])
        
        if len(answer.result) == 0:
            predicted = "no_answer"
        else:
            max_ans = max(answer.result, key=lambda x: answer.result[x])
            p = answer.result[max_ans]
            predicted = str(max_ans.args[gt_query.output_ind[0]])
        
        confusion_matrix.add_item(predicted, actual)
        all_labels.append(actual)
        all_preds.append(predicted)
    
    # Convert emotion labels to indices
    label_to_idx = {emo: i for i, emo in enumerate(fe_labels)}
    y_true = np.array([label_to_idx.get(label, -1) for label in all_labels])
    y_pred = np.array([label_to_idx.get(pred, -1) for pred in all_preds])
    
    # Remove any "no_answer" predictions (-1)
    valid_mask = (y_true >= 0) & (y_pred >= 0)
    y_true = y_true[valid_mask]
    y_pred = y_pred[valid_mask]
    
    # Calculate sklearn confusion matrix
    cm = sklearn_cm(y_true, y_pred, labels=range(len(fe_labels)))
    
    # Per-class metrics
    precision, recall, f1, support = precision_recall_fscore_support(
        y_true, y_pred, average=None, labels=range(len(fe_labels)), zero_division=0
    )
    
    # Overall accuracy
    accuracy = confusion_matrix.accuracy()
    result =  {
        'accuracy': accuracy,
        'confusion_matrix': cm,
        'dpl_confusion_matrix': confusion_matrix,
        'y_true': y_true,
        'y_pred': y_pred,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'support': support
    }
    print_dpl_detailed_metrics(result, fe_labels)

    model.train()
    return result


def print_dpl_detailed_metrics(results, label_names):
    """Print detailed metrics for DPL results"""
    print(f"\n{'='*70}")
    print(f"Overall Metrics:")
    print(f"{'='*70}")
    print(f"Accuracy: {results['accuracy']:.4f}")
    
    print(f"\n{'='*70}")
    print(f"Per-Class Metrics:")
    print(f"{'='*70}")
    print(f"{'Emotion':<15} {'Precision':<12} {'Recall':<12} {'F1-Score':<12} {'Support':<10}")
    print(f"{'-'*70}")
    
    for i, label in enumerate(label_names):
        print(f"{label:<15} {results['precision'][i]:<12.4f} "
              f"{results['recall'][i]:<12.4f} {results['f1'][i]:<12.4f} "
              f"{int(results['support'][i]):<10}")
    
    # Macro averages
    print(f"{'-'*70}")
    print(f"{'Macro Avg':<15} {results['precision'].mean():<12.4f} "
          f"{results['recall'].mean():<12.4f} {results['f1'].mean():<12.4f} "
          f"{int(results['support'].sum()):<10}")
    
    # Weighted averages
    weights = results['support'] / results['support'].sum()
    weighted_precision = (results['precision'] * weights).sum()
    weighted_recall = (results['recall'] * weights).sum()
    weighted_f1 = (results['f1'] * weights).sum()
    
    print(f"{'Weighted Avg':<15} {weighted_precision:<12.4f} "
          f"{weighted_recall:<12.4f} {weighted_f1:<12.4f} "
          f"{int(results['support'].sum()):<10}")

# %%
from deepproblog.engines import ApproximateEngine
heuristic2 = ApproximateEngine.geometric_mean

model = Model(os.path.join(prolog_dir, "model8.pl"), [scene_network, face_network, hybrid_emotion_network])
# model.set_engine(ExactEngine(model))
model.set_engine(ApproximateEngine(model, 30, heuristic2))
model.add_tensor_source("face_predictions", face_predictions)
model.add_tensor_source("scene_predictions", scene_predictions)
model.add_tensor_source("face_features", face_features)
model.add_tensor_source("scene_features", scene_features)

model.optimizer = SGD(model, 5e-2)

# %%
class FEQUeryDataset(DPLDataset):
    def __init__(self, indices):
        self.indices = indices

    def __len__(self):
        return len(self.indices)
    
    def __getitem__(self, index):
        pass

    def to_query(self, idx):
        idx = self.indices[idx]
        label_str = df.iloc[idx]['emotion']

        return Query(
            Term("final_emotion",
                Term("tensor", Term(f"face_predictions", Constant(idx))),
                Term("tensor", Term(f"scene_predictions", Constant(idx))),
                Term("tensor", Term(f"face_features", Constant(idx))),
                Term("tensor", Term(f"scene_features", Constant(idx))),
                Term(label_str)
                )
        )
    
train_dataset = FEQUeryDataset(train_indices)
test_dataset = FEQUeryDataset(test_indices[:1000])

# %%
train_loader = DPLDataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
def debug_query(model, pred_name, *args, substitution=None):
    """Helper to test intermediate predicates"""
    query = Query(Term(pred_name, *args), substitution=substitution)
    print(f"\n{'='*60}")
    print(f"Testing: {pred_name}")
    print(f"{'='*60}")
    model.eval()
    results = model.solve([query])
    result = results[0].result
    
    # Print probabilities nicely
    for key, prob in sorted(result.items(), key=lambda x: -x[1]):
        print(f"  {key}: {prob:.4f}")
    
    return result

# %%
test_idx = random.choice(test_indices)
show_pretrained_model_predictions_on_sample(test_idx)

debug_query(model,
            "test_va",
            Term("tensor", Term("face_predictions", Constant(test_idx))),
            Term("tensor", Term("scene_predictions", Constant(test_idx))),
            Var("FV"),
            Var("FA"),
            Var("SV"),
            Var("SA"))

debug_query(model,
            "test_combo",
            Term("tensor", Term("face_predictions", Constant(test_idx))),
            Term("tensor", Term("scene_predictions", Constant(test_idx))),
            Var("CA"),
            Var("CV"))

debug_query(model,
            "final_emotion",
            Term("tensor", Term("face_predictions", Constant(test_idx))),
            Term("tensor", Term("scene_predictions", Constant(test_idx))),
            Term("tensor", Term("face_features", Constant(test_idx))),
            Term("tensor", Term("scene_features", Constant(test_idx))),
            Var("Emotion"))

print("Debugging queries done.")
# Out:
# Base model (365 categories):
#   veterinarians_office: 0.2291
#   art_school: 0.1508
#   hospital_room: 0.0988
#
#
# ============================================================
# Testing: test_va
# ============================================================
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.83,2.95): 0.1998
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,4.13,2.62): 0.1315
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.59,2.89): 0.0862
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.65,2.99): 0.0794
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.84,2.58): 0.0676
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.59,2.6): 0.0473
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.89,2.73): 0.0397
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.87,2.56): 0.0362
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.79,2.52): 0.0309
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.09,3.08): 0.0239
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.53,2.58): 0.0145
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.49,2.45): 0.0125
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.54,2.52): 0.0112
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.06,3.03): 0.0088
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.4,2.68): 0.0076
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.55,2.92): 0.0070
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,2.75,2.8): 0.0045
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,4.06,2.83): 0.0042
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.73,2.0): 0.0039
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.65,2.9): 0.0039
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,4.16,2.41): 0.0037
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,4.77,2.51): 0.0036
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.57,2.52): 0.0031
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.51,2.8): 0.0025
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.88,2.45): 0.0024
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.56,2.48): 0.0022
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.48,3.18): 0.0021
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.5,2.23): 0.0021
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.71,2.45): 0.0019
#   test_va(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5,3.41,2.18): 0.0018
#
# ============================================================
# Testing: test_combo
# ============================================================
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.876666666666667,1.983333333333333): 0.1998
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.796666666666667,1.963333333333334): 0.0862
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.816666666666667,1.996666666666667): 0.0794
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.88,1.86): 0.0676
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),4.13,1.873333333333333): 0.0508
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.796666666666667,1.866666666666666): 0.0473
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.896666666666667,1.91): 0.0397
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.89,1.853333333333333): 0.0362
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.863333333333333,1.84): 0.0309
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.63,2.026666666666667): 0.0239
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.873333333333333): 0.0161
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.776666666666667,1.86): 0.0145
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.763333333333333,2.45): 0.0119
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.78,1.84): 0.0112
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.62,2.01): 0.0088
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.763333333333333,1.5): 0.0087
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.733333333333333,1.893333333333333): 0.0076
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.783333333333333,1.973333333333333): 0.0070
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.516666666666667,1.933333333333333): 0.0045
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.816666666666667,1.966666666666667): 0.0039
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.843333333333333,2.0): 0.0037
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),1.843333333333333,1.5): 0.0027
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),4.06,1.943333333333333): 0.0016
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),4.77,1.836666666666667): 0.0014
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),4.16,2.41): 0.0014
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),4.16,1.5): 0.0010
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.943333333333333): 0.0005
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.836666666666667): 0.0004
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,2.41): 0.0004
#   test_combo(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),0.9,1.5): 0.0003
#
# ============================================================
# Testing: final_emotion
# ============================================================
#   final_emotion(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),tensor(face_features(20973)),tensor(scene_features(20973)),sadness): 0.0788
#   final_emotion(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),tensor(face_features(20973)),tensor(scene_features(20973)),surprise): 0.0669
#   final_emotion(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),tensor(face_features(20973)),tensor(scene_features(20973)),anger): 0.0565
#   final_emotion(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),tensor(face_features(20973)),tensor(scene_features(20973)),anticipation): 0.0564
#   final_emotion(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),tensor(face_features(20973)),tensor(scene_features(20973)),fear): 0.0491
#   final_emotion(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),tensor(face_features(20973)),tensor(scene_features(20973)),trust): 0.0383
#   final_emotion(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),tensor(face_features(20973)),tensor(scene_features(20973)),joy): 0.0363
#   final_emotion(tensor(face_predictions(20973)),tensor(scene_predictions(20973)),tensor(face_features(20973)),tensor(scene_features(20973)),disgust): 0.0220
# Debugging queries done.

# %%
train_obj = train_model(
    model,
    train_loader,
    5,
    batch_size=batch_size,
    log_iter=log_iter,
    test_iter = 20 * log_iter,
    test=lambda x :[
        ("test_accuracy", evaluate_dpl_with_metrics(model, test_dataset)['accuracy'])
    ],
    initial_test = False
)
# Out:
# Training  for 5 epoch(s)
# Epoch 1
# Iteration:  2 	s:35.1963 	Average Loss:  1.1257518902420998
# 0.43100734477063274	0.5689926552293674	0.4233816567741512	0.5766183432258488	0.24582840276059056	0.7541715972394094	0.38910571517896825	0.6108942848210317
# Iteration:  4 	s:72.7136 	Average Loss:  2.3221379965543747
# 0.4437111329884532	0.5562888670115469	0.43697583916129806	0.5630241608387019	0.2682561449999721	0.7317438550000278	0.390303340040873	0.6096966599591269
# Iteration:  6 	s:67.6001 	Average Loss:  2.1748871030285954
# 0.45484409200900455	0.5451559079909956	0.45016036834910855	0.5498396316508914	0.286979052418642	0.7130209475813579	0.3917694441826532	0.6082305558173468
# Iteration:  8 	s:61.6324 	Average Loss:  2.1849865512922406
# 0.46529173174433397	0.5347082682556661	0.46205420008380416	0.5379457999161958	0.3068064128320125	0.6931935871679875	0.39250293180577106	0.6074970681942289
# Iteration:  10 	s:64.1527 	Average Loss:  1.882900780532509
# 0.47115456216603935	0.5288454378339607	0.46946211119265974	0.5305378888073402	0.3223173590203947	0.6776826409796053	0.39292254948105665	0.6070774505189432
# Iteration:  12 	s:64.0621 	Average Loss:  2.213759683072567
# 0.47672161794041407	0.5232783820595859	0.4758730115530755	0.5241269884469246	0.3449482816444579	0.6550517183555421	0.3939600408926958	0.6060399591073041
# Iteration:  14 	s:63.7886 	Average Loss:  2.359480624087155
# 0.4814695348696342	0.5185304651303658	0.48065477212148144	0.5193452278785187	0.3574007402923021	0.6425992597076978	0.3951639921503866	0.6048360078496134
# Iteration:  16 	s:63.5220 	Average Loss:  1.9313994096592069
# 0.4842322613321752	0.5157677386678249	0.48425427918313463	0.5157457208168653	0.37483462051914396	0.625165379480856	0.3966894963037696	0.6033105036962305
# Iteration:  18 	s:65.0759 	Average Loss:  2.105968833900988
# 0.48708496621865405	0.5129150337813461	0.4867767628407713	0.5132232371592286	0.38575029636767627	0.6142497036323238	0.39686385118651196	0.6031361488134881
# Iteration:  20 	s:65.2211 	Average Loss:  2.2396955341100693
# 0.48977893758467206	0.510221062415328	0.48990030532359574	0.5100996946764043	0.402359589791874	0.597640410208126	0.39726799417551756	0.6027320058244825
# Iteration:  22 	s:63.6791 	Average Loss:  1.9507859498262405
# 0.4917682457755853	0.5082317542244148	0.4917677516443526	0.5082322483556474	0.408528548219266	0.5914714517807339	0.3982088688554317	0.6017911311445684
# Iteration:  24 	s:65.2814 	Average Loss:  1.950015514390543
# 0.49377744635773535	0.5062225536422646	0.4933702178540818	0.5066297821459181	0.41378085237145346	0.5862191476285464	0.39853265876955063	0.6014673412304493
# Iteration:  26 	s:72.6511 	Average Loss:  2.2662744869012386
# 0.49489666482919104	0.505103335170809	0.4947831526322735	0.5052168473677264	0.4231145414824114	0.5768854585175885	0.39931587444972483	0.6006841255502752
# Iteration:  28 	s:72.9352 	Average Loss:  2.188447722233832
# 0.49554593324758983	0.5044540667524101	0.49575063628455773	0.5042493637154422	0.4327947364913144	0.5672052635086855	0.39998153102504214	0.6000184689749579
# Iteration:  30 	s:69.1838 	Average Loss:  2.0017675377894193
# 0.4965833522452928	0.5034166477547071	0.49670135996565373	0.5032986400343462	0.4400749577563917	0.5599250422436082	0.40113980254344817	0.598860197456552
# Iteration:  32 	s:76.0069 	Average Loss:  2.0860594557598233
# 0.4972596016666745	0.5027403983333254	0.4974957099843878	0.5025042900156121	0.4449328106209565	0.5550671893790434	0.40136140284294813	0.5986385971570519
# Iteration:  34 	s:65.1726 	Average Loss:  2.03809673152864
# 0.4975619804612647	0.5024380195387352	0.4978961284093313	0.5021038715906687	0.451270937084973	0.5487290629150269	0.40189131340925166	0.5981086865907483
# Iteration:  36 	s:76.9385 	Average Loss:  1.9006265746429563
# 0.49828282699814813	0.5017171730018517	0.4983936867930886	0.5016063132069113	0.4564544232069054	0.5435455767930946	0.40242682327952206	0.597573176720478
# Iteration:  38 	s:74.5932 	Average Loss:  2.2770690354518592
# 0.49912457596042265	0.5008754240395773	0.49889559205391243	0.5011044079460875	0.4604714554721822	0.5395285445278178	0.4028841099136769	0.5971158900863232
# Iteration:  40 	s:73.7138 	Average Loss:  2.120318714529276
# 0.4993800282599677	0.5006199717400323	0.49927498617971233	0.5007250138202876	0.46349737975365024	0.5365026202463498	0.4028880061046924	0.5971119938953077
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [420], line 1
# ----> 1 train_obj = train_model(
#       2     model,
#       3     train_loader,
#       4     5,
#       5     batch_size=batch_size,
#       6     log_iter=log_iter,
#       7     test_iter = 20 * log_iter,
#       8     test=lambda x :[
#       9         ("test_accuracy", evaluate_dpl_with_metrics(model, test_dataset)['accuracy'])
#      10     ],
#      11     initial_test = False
#      12 )
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\deepproblog\train.py:200, in train_model(model, loader, stop_condition, **kwargs)
#     193 def train_model(
#     194     model: Model,
#     195     loader: DataLoader,
#     196     stop_condition: Union[int, StopCondition],
#     197     **kwargs
#     198 ) -> TrainObject:
#     199     train_object = TrainObject(model)
# --> 200     train_object.train(loader, stop_condition, **kwargs)
#     201     return train_object
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\deepproblog\train.py:132, in TrainObject.train(self, loader, stop_criterion, verbose, loss_function_name, with_negatives, log_iter, initial_test, **kwargs)
#     129 self.accumulated_loss += loss
#     131 self.model.optimizer.step()
# --> 132 self.log(verbose=verbose, log_iter=log_iter, **kwargs)
#     133 for j, hook in self.hooks:
#     134     if self.i % j == 0:
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\deepproblog\train.py:185, in TrainObject.log(self, snapshot_iter, log_iter, test_iter, verbose, **kwargs)
#     183     self.prev_iter_time = iter_time
#     184 if "test" in kwargs and self.i % test_iter == 0:
# --> 185     value = kwargs["test"](self.model)
#     186     self.logger.log_list(self.i, value)
#     187     print("Test: ", value)
#
# Cell In [420], line 9, in <lambda>(x)
#       1 train_obj = train_model(
#       2     model,
#       3     train_loader,
#       4     5,
#       5     batch_size=batch_size,
#       6     log_iter=log_iter,
#       7     test_iter = 20 * log_iter,
#       8     test=lambda x :[
# ----> 9         ("test_accuracy", evaluate_dpl_with_metrics(model, test_dataset)['accuracy'])
#      10     ],
#      11     initial_test = False
#      12 )
#
# Cell In [414], line 17, in evaluate_dpl_with_metrics(model, dataset)
#      15 for i, gt_query in enumerate(tqdm(dataset.to_queries(), desc="Evaluating DPL", leave=False)):
#      16     test_query = gt_query.variable_output()
# ---> 17     answer = model.solve([test_query])[0]
#      18     actual = str(gt_query.output_values()[0])
#      20     if len(answer.result) == 0:
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\deepproblog\model.py:117, in Model.solve(self, batch)
#     116 def solve(self, batch: Sequence[Query]) -> List[Result]:
# --> 117     return self.solver.solve(batch)
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\deepproblog\solver.py:88, in Solver.solve(self, batch)
#      86 acs: List[ArithmeticCircuit] = [self.cache.get(q) for q in batch]
#      87 # Evaluate ACs. Evaluate networks if necessary
# ---> 88 result = [
#      89     ac.evaluate(self.model, batch[i].substitution) for i, ac in enumerate(acs)
#      90 ]
#      91 semirings = [r.semiring for r in result]
#      92 self.engine.perform_count(batch, (acs, semirings))
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\deepproblog\solver.py:89, in <listcomp>(.0)
#      86 acs: List[ArithmeticCircuit] = [self.cache.get(q) for q in batch]
#      87 # Evaluate ACs. Evaluate networks if necessary
#      88 result = [
# ---> 89     ac.evaluate(self.model, batch[i].substitution) for i, ac in enumerate(acs)
#      90 ]
#      91 semirings = [r.semiring for r in result]
#      92 self.engine.perform_count(batch, (acs, semirings))
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\deepproblog\arithmetic_circuit.py:60, in ArithmeticCircuit.evaluate(self, model, substitution, re_evaluate)
#      58 semiring = self.semiring(model, substitution, values)
#      59 start = time()
# ---> 60 evaluation = self.sdd.evaluate(semiring=semiring)
#      61 if substitution is not None:
#      62     evaluation = {k.apply_term(substitution): evaluation[k] for k in evaluation}
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\problog\evaluator.py:431, in Evaluatable.evaluate(self, index, semiring, evidence, weights, **kwargs)
#     427 # Probability of query given evidence
#     428
#     429 # interrupted = False
#     430 for name, node, label in evaluator.formula.labeled():
# --> 431     w = evaluator.evaluate(node)
#     432     result[name] = w
#     433 return result
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\problog\dd_formula.py:520, in DDEvaluator.evaluate(self, node)
#     518     return self.evaluate_standard(node)
#     519 else:
# --> 520     return self.evaluate_custom(node)
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\problog\sdd_formula.py:906, in SDDEvaluator.evaluate_custom(self, node)
#     904 smooth_to_root = self.semiring.is_nsp()
#     905 # perform_smoothing=True because of indicator variables # TODO There are no indicator variables in SDDs.
# --> 906 result = self._get_manager().wmc(
#     907     query_sdd,
#     908     weights=self.weights,
#     909     semiring=self.semiring,
#     910     pr_semiring=False,
#     911     perform_smoothing=True,
#     912     smooth_to_root=smooth_to_root,
#     913 )
#     915 self._get_manager().deref(query_sdd)
#     917 # TODO only normalize when there are evidence or constraints.
#     918 #            result = self.semiring.normalize(result, self.normalization)
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\problog\sdd_formula.py:481, in SDDManager.wmc(self, node, weights, semiring, literal, pr_semiring, perform_smoothing, smooth_to_root, wmc_func)
#     475 query_node = (
#     476     node if literal is None else self.get_manager().literal(literal)
#     477 )
#     478 sdd_iterator = SddIterator(
#     479     self.get_manager(), smooth_to_root=smooth_to_root
#     480 )
# --> 481 result = sdd_iterator.depth_first(query_node, wmc_func)
#     483 if weights.get(0) is not None:  # Times the weight of True
#     484     result = semiring.times(result, weights[0][0])
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\pysdd\iterator.py:106, in SddIterator.depth_first(self, node, func)
#     104     wmc = func(node, None, self._expected_vars[self.vtree.position()], set())
#     105 else:
# --> 106     wmc = self.depth_first_rec(node, func)
#     107 if self.smooth_to_root and not (node.is_true() or node.is_literal() or node.is_false()):
#     108     root = self.vtree.root()
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\pysdd\iterator.py:147, in SddIterator.depth_first_rec(self, node, func)
#     145 for prime, sub in node.elements():
#     146     wmc_prime = self.depth_first_rec(prime, func)
# --> 147     wmc_sub = self.depth_first_rec(sub, func)
#     148     if not self.smooth:
#     149         used_prime_vars = None
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\pysdd\iterator.py:146, in SddIterator.depth_first_rec(self, node, func)
#     144     expected_sub_vars = self._expected_vars[vtree_right.position()]
#     145 for prime, sub in node.elements():
# --> 146     wmc_prime = self.depth_first_rec(prime, func)
#     147     wmc_sub = self.depth_first_rec(sub, func)
#     148     if not self.smooth:
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\pysdd\iterator.py:146, in SddIterator.depth_first_rec(self, node, func)
#     144     expected_sub_vars = self._expected_vars[vtree_right.position()]
#     145 for prime, sub in node.elements():
# --> 146     wmc_prime = self.depth_first_rec(prime, func)
#     147     wmc_sub = self.depth_first_rec(sub, func)
#     148     if not self.smooth:
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\pysdd\iterator.py:161, in SddIterator.depth_first_rec(self, node, func)
#     159                 used_sub_vars = self._expected_vars[sub.vtree().position()]
#     160         rvalues.append((wmc_prime, wmc_sub, used_prime_vars, used_sub_vars))
# --> 161     rvalue = func(node, rvalues, expected_prime_vars, expected_sub_vars)
#     162 else:
#     163     rvalue = func(node, None, None, None)
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\problog\sdd_formula.py:597, in SDDManager._get_wmc_func.<locals>.func_weightedmodelcounting(node, rvalues, expected_prime_vars, expected_sub_vars)
#     591         missing_pos_weight, missing_neg_weight = weights[
#     592             missing_literal
#     593         ]
#     594         missing_combined_weight = semiring.plus(
#     595             missing_pos_weight, missing_neg_weight
#     596         )
# --> 597         branch_weight = semiring.times(
#     598             branch_weight, missing_combined_weight
#     599         )
#     601 # Add to current intermediate result
#     602 if result_weight is not None:
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\deepproblog\semiring\graph_semiring.py:39, in GraphSemiring.times(self, a, b)
#      38 def times(self, a, b):
# ---> 39     if self.is_one(b):
#      40         return a
#      41     if self.is_one(a):
#
# File c:\Users\jarne\miniconda3\envs\dpl_base\lib\site-packages\deepproblog\semiring\graph_semiring.py:74, in GraphSemiring.is_one(self, a)
#      73 def is_one(self, a):
# ---> 74     return 1.0 - self.eps <= float(a) <= 1.0 + self.eps
#
# KeyboardInterrupt:
